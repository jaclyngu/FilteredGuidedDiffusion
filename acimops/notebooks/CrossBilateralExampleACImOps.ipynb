# %%
from apy import *
from apy.afileui import *
from apy.amedia import *

# %%
# OpenCWD()

# %%
guide = Image("./inputs/flash.png");
guide.show()

im = Image("./inputs/noflash.png")
im.show()

# %% [markdown]
# ### Cross Bilateral
# The sigmas are [sigmay, sigmax, sigmavalue]

# %%
# getCrossBilateralFiltered
filtered = im.GetCrossBilateralFiltered(guide=guide, sigmas=[5,5,0.05]);
filtered.show()
